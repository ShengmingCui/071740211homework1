# %%
import numpy as np
import math
import matplotlib.pyplot as plt
g=9.8
dt=0.01
H=100
vy1=0
vy2=0
t=0
H1=[]
T1=[]
def adams(vy1,vy2,H):
    vy1=vy1+g*dt
    H=H-0.5*dt*(3*vy1-vy2)
    vy2=vy1
    return vy1,vy2,H
while t <= 5:
        vy1,vy2,H=adams(vy1,vy2,H)
        t+=dt
        T1.append(t) 
        H1.append(H)
H=H1[i]
t=T1[i]
plt.plot(T1,H1)
